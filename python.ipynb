# %%
import pickle

# %%
f = open(("datasets/WADI/processed/WADI_test.pkl"), "rb")
train_data = pickle.load(f)

# %%
train_data.shape
# Out:
# (172803, 127)

# %%
train_data[:3,:]
# Out:
# array([[ 1.64210e+02,  5.29486e-01,  1.19972e+01,  4.82480e+02,
#          3.31167e-01,  1.27323e-03,  0.00000e+00,  0.00000e+00,
#          4.84820e+01,  1.00000e+00,  1.00000e+00,  1.00000e+00,
#          1.00000e+00,  1.00000e+00,  1.00000e+00,  1.00000e+00,
#          1.00000e+00,  1.00000e+00,  1.00000e+00,  2.53870e+03,
#          3.56659e+01,  2.40392e-01,  2.00000e-01,  6.85648e+01,
#          3.06246e-01,  1.00000e-01,  1.00000e+02,  4.65504e-02,
#          1.00000e-01,  2.00701e+01,  1.75445e-01,  9.00000e-02,
#          1.00000e+02,  4.87998e-02,  1.10000e-01,  1.00000e+02,
#          5.11665e-02,  1.50000e-01,  0.00000e+00,  6.19690e-01,
#          0.00000e+00,  2.39192e-01,  3.10242e-01,  4.65504e-02,
#          1.70598e-01,  4.87998e-02,  5.11665e-02,          nan,
#                  nan,  0.00000e+00,  0.00000e+00,  0.00000e+00,
#          0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00,
#          0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00,
# ...
